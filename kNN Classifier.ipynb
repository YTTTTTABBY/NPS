# %% [markdown]
# <a href="https://colab.research.google.com/github/YTTTTTABBY/NPS/blob/main/kNN%20Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Core code adapted from a coding assignment in IT1244. Credit to Dr Prabhu for finding/creating the initial code.
### Datasets used are adapted from https://archive.ics.uci.edu/dataset/856/higher+education+students+performance+evaluation

# file manipulation
import csv

# numerical data processing
import numpy as np

np.set_printoptions(precision=4, suppress=True)

# %%
# loading data
X_COLUMN_NAMES = [
    "AGE", # 1: 18-21, 2: 22-25, 3: above 26
    "CCA", # 1: Yes, 2: No
    "CAMPUS", # 1: Yes, 2: No
    "YEAR", # 1:1, 2:2, 3:3, 4:4
    "GPA", # 1: <3.00, 2: 3.00-3.49, 3: 3.50-3.99, 4: 4.00-4.49, 5: above 4.49
]
Y_COLUMN_NAME = "ID" # ID of the student/tourist

# function to load files
def load_data(filename):
    X, y = None, None

    Xlist=[]
    ylist=[]
    with open(filename,"r") as f:
      reader=csv.reader(f,delimiter=',')
      titles = reader.__next__()
      lookup = [titles.index(x) for x in X_COLUMN_NAMES]
      lookupy = titles.index(Y_COLUMN_NAME)
      for row in reader:
        Xlist.append([row[x] for x in lookup])
        ylist.append(row[lookupy])
      X=np.asarray(Xlist,dtype=float)
      y=np.asarray(ylist,dtype=float)

    return X, y

# loading student data
filename = "/content/Student Data.csv"
Xs, ys = load_data(filename)

# loading tourist data
filename = "/content/Tourist Data.csv"
Xt, yt = load_data(filename)

# %%
#normalising data
def normalise(dataset):
  X_norm = np.zeros_like(dataset)

  mini = np.amin(dataset,axis=0)
  maxi = np.amax(dataset,axis=0)
  X_norm=np.array([((x-mini)/(maxi-mini)) for x in dataset])

  return X_norm

Xs_norm = normalise(Xs)
Xt_norm = normalise(Xt)

# %%
# computing euclidean distance between points
def euclideanDist(x1, x2):
    dist = np.sqrt(np.sum(np.square(x1 - x2)))

    return dist

# finding the nearest neighbours and their IDs
def kNearestNeighbors(X, y, Xtest, K):

    Xng, yng = None, None
      # calculate the distance between Xtest and every sample in X
    dist_list=[]
    for i in range(len(X)):
      Xdist = euclideanDist(Xtest, X[i, :])
      dist_list.append(Xdist)

    dists = np.array(dist_list)

    # Finding the nearest K neighbours from nearest to Kth nearest
    index = np.argsort(dists)[:K]
    Xng = X[index]
    yng = y[index]
    return Xng, yng

# %%
# driver code to test the function
K = 3
Xng, yng = kNearestNeighbors(Xs_norm, ys, Xt_norm[12], K)

print(Xng) # X values of chosen students
print(Xt_norm[14]) # Check X values of the tourist to manually validate closeness of matchs
print(yng) #ID of chosen students
# Out:
# [[0.   1.   1.   0.   0.75]
#  [0.   1.   1.   0.   0.75]
#  [0.   1.   1.   0.   0.75]]
# [0.5    0.     1.     0.3333 0.25  ]
# [62. 86. 35.]

# %%
# testing the algorithm for matching multiple tourists
K=3
for i in range(5):
  Xng, yng = kNearestNeighbors(Xs_norm, ys, Xt_norm[i], K)
  print("For Tourist ", yt[i],":")
  print("Choice 1: Student #", yng[0])
  print("Choice 2: Student #", yng[1])
  print("Choice 3: Student #", yng[2])
# Out:
# For Tourist  1.0 :
# Choice 1: Student # 90.0
# Choice 2: Student # 59.0
# Choice 3: Student # 64.0
# For Tourist  2.0 :
# Choice 1: Student # 27.0
# Choice 2: Student # 5.0
# Choice 3: Student # 18.0
# For Tourist  3.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 16.0
# Choice 3: Student # 27.0
# For Tourist  4.0 :
# Choice 1: Student # 96.0
# Choice 2: Student # 38.0
# Choice 3: Student # 31.0
# For Tourist  5.0 :
# Choice 1: Student # 21.0
# Choice 2: Student # 96.0
# Choice 3: Student # 28.0

# %%
# matching every tourist in the dataset to 3 potential students
K=3
for i in range(len(yt)):
  Xng, yng = kNearestNeighbors(Xs_norm, ys, Xt_norm[i], K)
  print("For Tourist ", yt[i],":")
  print("Choice 1: Student #", yng[0])
  print("Choice 2: Student #", yng[1])
  print("Choice 3: Student #", yng[2])
# Out:
# For Tourist  1.0 :
# Choice 1: Student # 90.0
# Choice 2: Student # 59.0
# Choice 3: Student # 64.0
# For Tourist  2.0 :
# Choice 1: Student # 27.0
# Choice 2: Student # 5.0
# Choice 3: Student # 18.0
# For Tourist  3.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 16.0
# Choice 3: Student # 27.0
# For Tourist  4.0 :
# Choice 1: Student # 96.0
# Choice 2: Student # 38.0
# Choice 3: Student # 31.0
# For Tourist  5.0 :
# Choice 1: Student # 21.0
# Choice 2: Student # 96.0
# Choice 3: Student # 28.0
# For Tourist  6.0 :
# Choice 1: Student # 77.0
# Choice 2: Student # 5.0
# Choice 3: Student # 27.0
# For Tourist  7.0 :
# Choice 1: Student # 100.0
# Choice 2: Student # 43.0
# Choice 3: Student # 111.0
# For Tourist  8.0 :
# Choice 1: Student # 122.0
# Choice 2: Student # 121.0
# Choice 3: Student # 136.0
# For Tourist  9.0 :
# Choice 1: Student # 121.0
# Choice 2: Student # 122.0
# Choice 3: Student # 136.0
# For Tourist  10.0 :
# Choice 1: Student # 23.0
# Choice 2: Student # 68.0
# Choice 3: Student # 2.0
# For Tourist  11.0 :
# Choice 1: Student # 20.0
# Choice 2: Student # 97.0
# Choice 3: Student # 50.0
# For Tourist  12.0 :
# Choice 1: Student # 11.0
# Choice 2: Student # 105.0
# Choice 3: Student # 129.0
# For Tourist  13.0 :
# Choice 1: Student # 62.0
# Choice 2: Student # 86.0
# Choice 3: Student # 35.0
# For Tourist  14.0 :
# Choice 1: Student # 77.0
# Choice 2: Student # 5.0
# Choice 3: Student # 27.0
# For Tourist  15.0 :
# Choice 1: Student # 61.0
# Choice 2: Student # 109.0
# Choice 3: Student # 117.0
# For Tourist  16.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 16.0
# Choice 3: Student # 27.0
# For Tourist  17.0 :
# Choice 1: Student # 14.0
# Choice 2: Student # 9.0
# Choice 3: Student # 120.0
# For Tourist  18.0 :
# Choice 1: Student # 77.0
# Choice 2: Student # 5.0
# Choice 3: Student # 27.0
# For Tourist  19.0 :
# Choice 1: Student # 67.0
# Choice 2: Student # 95.0
# Choice 3: Student # 74.0
# For Tourist  20.0 :
# Choice 1: Student # 96.0
# Choice 2: Student # 98.0
# Choice 3: Student # 106.0
# For Tourist  21.0 :
# Choice 1: Student # 23.0
# Choice 2: Student # 68.0
# Choice 3: Student # 2.0
# For Tourist  22.0 :
# Choice 1: Student # 38.0
# Choice 2: Student # 37.0
# Choice 3: Student # 83.0
# For Tourist  23.0 :
# Choice 1: Student # 83.0
# Choice 2: Student # 37.0
# Choice 3: Student # 58.0
# For Tourist  24.0 :
# Choice 1: Student # 120.0
# Choice 2: Student # 70.0
# Choice 3: Student # 54.0
# For Tourist  25.0 :
# Choice 1: Student # 90.0
# Choice 2: Student # 64.0
# Choice 3: Student # 39.0
# For Tourist  26.0 :
# Choice 1: Student # 23.0
# Choice 2: Student # 68.0
# Choice 3: Student # 2.0
# For Tourist  27.0 :
# Choice 1: Student # 53.0
# Choice 2: Student # 69.0
# Choice 3: Student # 141.0
# For Tourist  28.0 :
# Choice 1: Student # 62.0
# Choice 2: Student # 86.0
# Choice 3: Student # 35.0
# For Tourist  29.0 :
# Choice 1: Student # 38.0
# Choice 2: Student # 37.0
# Choice 3: Student # 83.0
# For Tourist  30.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 77.0
# Choice 3: Student # 27.0
# For Tourist  31.0 :
# Choice 1: Student # 144.0
# Choice 2: Student # 81.0
# Choice 3: Student # 69.0
# For Tourist  32.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 39.0
# Choice 3: Student # 45.0
# For Tourist  33.0 :
# Choice 1: Student # 77.0
# Choice 2: Student # 5.0
# Choice 3: Student # 27.0
# For Tourist  34.0 :
# Choice 1: Student # 58.0
# Choice 2: Student # 92.0
# Choice 3: Student # 31.0
# For Tourist  35.0 :
# Choice 1: Student # 106.0
# Choice 2: Student # 98.0
# Choice 3: Student # 28.0
# For Tourist  36.0 :
# Choice 1: Student # 89.0
# Choice 2: Student # 71.0
# Choice 3: Student # 76.0
# For Tourist  37.0 :
# Choice 1: Student # 24.0
# Choice 2: Student # 2.0
# Choice 3: Student # 68.0
# For Tourist  38.0 :
# Choice 1: Student # 122.0
# Choice 2: Student # 121.0
# Choice 3: Student # 136.0
# For Tourist  39.0 :
# Choice 1: Student # 88.0
# Choice 2: Student # 84.0
# Choice 3: Student # 26.0
# For Tourist  40.0 :
# Choice 1: Student # 1.0
# Choice 2: Student # 68.0
# Choice 3: Student # 2.0
# For Tourist  41.0 :
# Choice 1: Student # 36.0
# Choice 2: Student # 93.0
# Choice 3: Student # 66.0
# For Tourist  42.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 16.0
# Choice 3: Student # 27.0
# For Tourist  43.0 :
# Choice 1: Student # 61.0
# Choice 2: Student # 109.0
# Choice 3: Student # 117.0
# For Tourist  44.0 :
# Choice 1: Student # 23.0
# Choice 2: Student # 2.0
# Choice 3: Student # 68.0
# For Tourist  45.0 :
# Choice 1: Student # 24.0
# Choice 2: Student # 2.0
# Choice 3: Student # 68.0
# For Tourist  46.0 :
# Choice 1: Student # 58.0
# Choice 2: Student # 92.0
# Choice 3: Student # 31.0
# For Tourist  47.0 :
# Choice 1: Student # 23.0
# Choice 2: Student # 2.0
# Choice 3: Student # 68.0
# For Tourist  48.0 :
# Choice 1: Student # 1.0
# Choice 2: Student # 68.0
# Choice 3: Student # 2.0
# For Tourist  49.0 :
# Choice 1: Student # 81.0
# Choice 2: Student # 121.0
# Choice 3: Student # 141.0
# For Tourist  50.0 :
# Choice 1: Student # 41.0
# Choice 2: Student # 49.0
# Choice 3: Student # 102.0
# For Tourist  51.0 :
# Choice 1: Student # 2.0
# Choice 2: Student # 68.0
# Choice 3: Student # 1.0
# For Tourist  52.0 :
# Choice 1: Student # 9.0
# Choice 2: Student # 14.0
# Choice 3: Student # 91.0
# For Tourist  53.0 :
# Choice 1: Student # 45.0
# Choice 2: Student # 80.0
# Choice 3: Student # 6.0
# For Tourist  54.0 :
# Choice 1: Student # 14.0
# Choice 2: Student # 9.0
# Choice 3: Student # 91.0
# For Tourist  55.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 16.0
# Choice 3: Student # 27.0
# For Tourist  56.0 :
# Choice 1: Student # 38.0
# Choice 2: Student # 92.0
# Choice 3: Student # 58.0
# For Tourist  57.0 :
# Choice 1: Student # 14.0
# Choice 2: Student # 9.0
# Choice 3: Student # 91.0
# For Tourist  58.0 :
# Choice 1: Student # 120.0
# Choice 2: Student # 70.0
# Choice 3: Student # 54.0
# For Tourist  59.0 :
# Choice 1: Student # 58.0
# Choice 2: Student # 92.0
# Choice 3: Student # 31.0
# For Tourist  60.0 :
# Choice 1: Student # 141.0
# Choice 2: Student # 52.0
# Choice 3: Student # 69.0
# For Tourist  61.0 :
# Choice 1: Student # 90.0
# Choice 2: Student # 64.0
# Choice 3: Student # 39.0
# For Tourist  62.0 :
# Choice 1: Student # 91.0
# Choice 2: Student # 109.0
# Choice 3: Student # 14.0
# For Tourist  63.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 16.0
# Choice 3: Student # 27.0
# For Tourist  64.0 :
# Choice 1: Student # 23.0
# Choice 2: Student # 2.0
# Choice 3: Student # 68.0
# For Tourist  65.0 :
# Choice 1: Student # 27.0
# Choice 2: Student # 5.0
# Choice 3: Student # 18.0
# For Tourist  66.0 :
# Choice 1: Student # 23.0
# Choice 2: Student # 2.0
# Choice 3: Student # 68.0
# For Tourist  67.0 :
# Choice 1: Student # 58.0
# Choice 2: Student # 92.0
# Choice 3: Student # 31.0
# For Tourist  68.0 :
# Choice 1: Student # 91.0
# Choice 2: Student # 109.0
# Choice 3: Student # 14.0
# For Tourist  69.0 :
# Choice 1: Student # 67.0
# Choice 2: Student # 95.0
# Choice 3: Student # 74.0
# For Tourist  70.0 :
# Choice 1: Student # 2.0
# Choice 2: Student # 68.0
# Choice 3: Student # 1.0
# For Tourist  71.0 :
# Choice 1: Student # 115.0
# Choice 2: Student # 79.0
# Choice 3: Student # 116.0
# For Tourist  72.0 :
# Choice 1: Student # 29.0
# Choice 2: Student # 87.0
# Choice 3: Student # 63.0
# For Tourist  73.0 :
# Choice 1: Student # 121.0
# Choice 2: Student # 122.0
# Choice 3: Student # 79.0
# For Tourist  74.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 39.0
# Choice 3: Student # 45.0
# For Tourist  75.0 :
# Choice 1: Student # 90.0
# Choice 2: Student # 64.0
# Choice 3: Student # 39.0
# For Tourist  76.0 :
# Choice 1: Student # 91.0
# Choice 2: Student # 109.0
# Choice 3: Student # 61.0
# For Tourist  77.0 :
# Choice 1: Student # 19.0
# Choice 2: Student # 143.0
# Choice 3: Student # 138.0
# For Tourist  78.0 :
# Choice 1: Student # 94.0
# Choice 2: Student # 28.0
# Choice 3: Student # 98.0
# For Tourist  79.0 :
# Choice 1: Student # 14.0
# Choice 2: Student # 9.0
# Choice 3: Student # 120.0
# For Tourist  80.0 :
# Choice 1: Student # 45.0
# Choice 2: Student # 80.0
# Choice 3: Student # 6.0
# For Tourist  81.0 :
# Choice 1: Student # 2.0
# Choice 2: Student # 68.0
# Choice 3: Student # 1.0
# For Tourist  82.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 39.0
# Choice 3: Student # 45.0
# For Tourist  83.0 :
# Choice 1: Student # 23.0
# Choice 2: Student # 2.0
# Choice 3: Student # 68.0
# For Tourist  84.0 :
# Choice 1: Student # 27.0
# Choice 2: Student # 5.0
# Choice 3: Student # 18.0
# For Tourist  85.0 :
# Choice 1: Student # 56.0
# Choice 2: Student # 85.0
# Choice 3: Student # 82.0
# For Tourist  86.0 :
# Choice 1: Student # 67.0
# Choice 2: Student # 95.0
# Choice 3: Student # 74.0
# For Tourist  87.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 16.0
# Choice 3: Student # 27.0
# For Tourist  88.0 :
# Choice 1: Student # 117.0
# Choice 2: Student # 40.0
# Choice 3: Student # 33.0
# For Tourist  89.0 :
# Choice 1: Student # 115.0
# Choice 2: Student # 79.0
# Choice 3: Student # 116.0
# For Tourist  90.0 :
# Choice 1: Student # 90.0
# Choice 2: Student # 64.0
# Choice 3: Student # 39.0
# For Tourist  91.0 :
# Choice 1: Student # 122.0
# Choice 2: Student # 121.0
# Choice 3: Student # 136.0
# For Tourist  92.0 :
# Choice 1: Student # 144.0
# Choice 2: Student # 81.0
# Choice 3: Student # 69.0
# For Tourist  93.0 :
# Choice 1: Student # 45.0
# Choice 2: Student # 80.0
# Choice 3: Student # 6.0
# For Tourist  94.0 :
# Choice 1: Student # 38.0
# Choice 2: Student # 37.0
# Choice 3: Student # 83.0
# For Tourist  95.0 :
# Choice 1: Student # 58.0
# Choice 2: Student # 92.0
# Choice 3: Student # 31.0
# For Tourist  96.0 :
# Choice 1: Student # 122.0
# Choice 2: Student # 121.0
# Choice 3: Student # 136.0
# For Tourist  97.0 :
# Choice 1: Student # 113.0
# Choice 2: Student # 136.0
# Choice 3: Student # 121.0
# For Tourist  98.0 :
# Choice 1: Student # 30.0
# Choice 2: Student # 51.0
# Choice 3: Student # 55.0
# For Tourist  99.0 :
# Choice 1: Student # 61.0
# Choice 2: Student # 109.0
# Choice 3: Student # 117.0
# For Tourist  100.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 16.0
# Choice 3: Student # 27.0
# For Tourist  101.0 :
# Choice 1: Student # 100.0
# Choice 2: Student # 3.0
# Choice 3: Student # 43.0
# For Tourist  102.0 :
# Choice 1: Student # 1.0
# Choice 2: Student # 2.0
# Choice 3: Student # 68.0
# For Tourist  103.0 :
# Choice 1: Student # 1.0
# Choice 2: Student # 68.0
# Choice 3: Student # 2.0
# For Tourist  104.0 :
# Choice 1: Student # 96.0
# Choice 2: Student # 106.0
# Choice 3: Student # 98.0
# For Tourist  105.0 :
# Choice 1: Student # 88.0
# Choice 2: Student # 84.0
# Choice 3: Student # 26.0
# For Tourist  106.0 :
# Choice 1: Student # 14.0
# Choice 2: Student # 9.0
# Choice 3: Student # 120.0
# For Tourist  107.0 :
# Choice 1: Student # 61.0
# Choice 2: Student # 124.0
# Choice 3: Student # 33.0
# For Tourist  108.0 :
# Choice 1: Student # 91.0
# Choice 2: Student # 132.0
# Choice 3: Student # 142.0
# For Tourist  109.0 :
# Choice 1: Student # 72.0
# Choice 2: Student # 138.0
# Choice 3: Student # 105.0
# For Tourist  110.0 :
# Choice 1: Student # 127.0
# Choice 2: Student # 137.0
# Choice 3: Student # 140.0
# For Tourist  111.0 :
# Choice 1: Student # 51.0
# Choice 2: Student # 16.0
# Choice 3: Student # 27.0
# For Tourist  112.0 :
# Choice 1: Student # 105.0
# Choice 2: Student # 11.0
# Choice 3: Student # 135.0
# For Tourist  113.0 :
# Choice 1: Student # 3.0
# Choice 2: Student # 43.0
# Choice 3: Student # 100.0
# For Tourist  114.0 :
# Choice 1: Student # 88.0
# Choice 2: Student # 84.0
# Choice 3: Student # 26.0
# For Tourist  115.0 :
# Choice 1: Student # 124.0
# Choice 2: Student # 117.0
# Choice 3: Student # 40.0
# For Tourist  116.0 :
# Choice 1: Student # 2.0
# Choice 2: Student # 68.0
# Choice 3: Student # 1.0
# For Tourist  117.0 :
# Choice 1: Student # 67.0
# Choice 2: Student # 95.0
# Choice 3: Student # 74.0
# For Tourist  118.0 :
# Choice 1: Student # 105.0
# Choice 2: Student # 11.0
# Choice 3: Student # 135.0
# For Tourist  119.0 :
# Choice 1: Student # 81.0
# Choice 2: Student # 121.0
# Choice 3: Student # 141.0
# For Tourist  120.0 :
# Choice 1: Student # 61.0
# Choice 2: Student # 109.0
# Choice 3: Student # 117.0
# For Tourist  121.0 :
# Choice 1: Student # 127.0
# Choice 2: Student # 137.0
# Choice 3: Student # 140.0
# For Tourist  122.0 :
# Choice 1: Student # 69.0
# Choice 2: Student # 53.0
# Choice 3: Student # 144.0
# For Tourist  123.0 :
# Choice 1: Student # 117.0
# Choice 2: Student # 40.0
# Choice 3: Student # 33.0
# For Tourist  124.0 :
# Choice 1: Student # 59.0
# Choice 2: Student # 60.0
# Choice 3: Student # 25.0
# For Tourist  125.0 :
# Choice 1: Student # 121.0
# Choice 2: Student # 136.0
# Choice 3: Student # 122.0
# For Tourist  126.0 :
# Choice 1: Student # 91.0
# Choice 2: Student # 132.0
# Choice 3: Student # 142.0
# For Tourist  127.0 :
# Choice 1: Student # 127.0
# Choice 2: Student # 137.0
# Choice 3: Student # 140.0
# For Tourist  128.0 :
# Choice 1: Student # 100.0
# Choice 2: Student # 3.0
# Choice 3: Student # 43.0
# For Tourist  129.0 :
# Choice 1: Student # 121.0
# Choice 2: Student # 136.0
# Choice 3: Student # 122.0
# For Tourist  130.0 :
# Choice 1: Student # 120.0
# Choice 2: Student # 70.0
# Choice 3: Student # 54.0
# For Tourist  131.0 :
# Choice 1: Student # 120.0
# Choice 2: Student # 70.0
# Choice 3: Student # 54.0
# For Tourist  132.0 :
# Choice 1: Student # 105.0
# Choice 2: Student # 11.0
# Choice 3: Student # 135.0
# For Tourist  133.0 :
# Choice 1: Student # 135.0
# Choice 2: Student # 19.0
# Choice 3: Student # 13.0
# For Tourist  134.0 :
# Choice 1: Student # 1.0
# Choice 2: Student # 2.0
# Choice 3: Student # 68.0
# For Tourist  135.0 :
# Choice 1: Student # 61.0
# Choice 2: Student # 109.0
# Choice 3: Student # 114.0
# For Tourist  136.0 :
# Choice 1: Student # 61.0
# Choice 2: Student # 124.0
# Choice 3: Student # 33.0
# For Tourist  137.0 :
# Choice 1: Student # 113.0
# Choice 2: Student # 136.0
# Choice 3: Student # 121.0
# For Tourist  138.0 :
# Choice 1: Student # 138.0
# Choice 2: Student # 72.0
# Choice 3: Student # 19.0
# For Tourist  139.0 :
# Choice 1: Student # 122.0
# Choice 2: Student # 121.0
# Choice 3: Student # 136.0
# For Tourist  140.0 :
# Choice 1: Student # 1.0
# Choice 2: Student # 2.0
# Choice 3: Student # 68.0
# For Tourist  141.0 :
# Choice 1: Student # 61.0
# Choice 2: Student # 109.0
# Choice 3: Student # 117.0
# For Tourist  142.0 :
# Choice 1: Student # 95.0
# Choice 2: Student # 74.0
# Choice 3: Student # 67.0
# For Tourist  143.0 :
# Choice 1: Student # 62.0
# Choice 2: Student # 86.0
# Choice 3: Student # 35.0
# For Tourist  144.0 :
# Choice 1: Student # 122.0
# Choice 2: Student # 121.0
# Choice 3: Student # 136.0
# For Tourist  145.0 :
# Choice 1: Student # 89.0
# Choice 2: Student # 71.0
# Choice 3: Student # 76.0
